# %%
from keras.models import Model, model_from_json, load_model

import matplotlib.pyplot as plt
import scipy.misc
import numpy as np
import os

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "" # do not use the GPU

# %%
nb_classes = 5
# input image dimensions
img_rows = img_cols = 512
layers = 3  

#Load a existing model architecture
filepath = "Json2016-11-17.txt"
with open(filepath, 'r') as myfile:
    json_string=myfile.read()

model = model_from_json(json_string)
#load Weights 
model.load_weights("2016-11-17_eph_126_acc_0.58.hdf5")


testPath = "retina_images"
X_test = np.load(os.path.join(testPath, "images_1.npy"))  
y_test = np.load(os.path.join(testPath, "labels_1.npy")) 

for k,img in enumerate(X_test[0:6]):
    prob = model.predict_proba(np.expand_dims(img,axis=0), batch_size=1, verbose=0)
    cl = np.argmax(prob)
    print(prob)
    print('class:',cl)
    implot = np.rollaxis(img,0,3)
    plt.figure(figsize=(6,6))
    plt.imshow(implot[:,:,::-1])
    plt.show()
    scipy.misc.imsave('image_'+str(k)+'_class_'+str(cl)+'.jpg', implot)
# Out:
# [[ 0.25652874  0.43248048  0.23211865  0.02865219  0.05022002]]
# ('class:', 1)
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-0e18ec6322b1> in <module>()
#      27     plt.imshow(implot[:,:,::-1])
#      28     plt.show()
# ---> 29     scipy.misc.imsave('sample/image_'+str(k)+'_class_'+str(cl)+'.jpg', implot)
#
# /home/jeremie/anaconda2/envs/tsflow/lib/python2.7/site-packages/scipy/misc/pilutil.pyc in imsave(name, arr, format)
#     195     im = toimage(arr, channel_axis=2)
#     196     if format is None:
# --> 197         im.save(name)
#     198     else:
#     199         im.save(name, format)
#
# /home/jeremie/anaconda2/envs/tsflow/lib/python2.7/site-packages/PIL/Image.pyc in save(self, fp, format, **params)
#    1680
#    1681         if open_fp:
# -> 1682             fp = builtins.open(filename, "wb")
#    1683
#    1684         try:
#
# IOError: [Errno 2] No such file or directory: 'sample/image_0_class_1.jpg'

# %%
# launching the visualization server
from quiver_engine import server

server.launch(model, temp_folder='./tmp', input_folder='./', port=7777)
